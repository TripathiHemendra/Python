# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
data2=pd.read_excel("D:\student.xlsx")

print(data2.duplicated(["department"]).sum())
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\user\AppData\Local\Temp\ipykernel_18856\4154966825.py:2: SyntaxWarning: invalid escape sequence '\s'
#   data2=pd.read_excel("D:\student.xlsx")
# 2

# %%
print("How are you mister☺️")
# Out:
# How are you mister☺️

# %%
a="Happy holi"
print(a," Himanshu")
# Out:
# Happy holi  Himanshu

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print("*",end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
